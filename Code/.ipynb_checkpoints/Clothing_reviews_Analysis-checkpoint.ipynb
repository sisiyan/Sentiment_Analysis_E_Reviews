# %% [markdown]
# # Project: Setiment Analysis for Women's Clothing E-Commerce
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# ## Introduction

# %%
# Load in packages

# data processing
import numpy as np
import pandas as pd
import nltk
import random
import os
from os import path

# Plotting packages
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# ### Check General Properties

# %%
# Read and Check the Data
df = pd.read_csv("../input/Womens Clothing E-Commerce Reviews.csv")
df.drop(df.columns[0],inplace=True, axis=1)
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df.shape
# Out:
# (23486, 10)

# %%
#Check the data type of each column and whether they have null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 10 columns):
# Clothing ID                23486 non-null int64
# Age                        23486 non-null int64
# Title                      19676 non-null object
# Review Text                22641 non-null object
# Rating                     23486 non-null int64
# Recommended IND            23486 non-null int64
# Positive Feedback Count    23486 non-null int64
# Division Name              23472 non-null object
# Department Name            23472 non-null object
# Class Name                 23472 non-null object
# dtypes: int64(5), object(5)
# memory usage: 1.8+ MB

# %%
# Change the column names to single words
type(df.columns)
column_names = []
for i in range(df.shape[1]):
    column_names.append(df.columns[i].strip().replace(" ","_")) 
df.columns = column_names
df.head(1)
# Out:
#    Clothing_ID  Age Title                                        Review_Text  \
# 0          767   33   NaN  Absolutely wonderful - silky and sexy and comf...
#
#    Rating  Recommended_IND  Positive_Feedback_Count Division_Name  \
# 0       4                1                        0     Initmates
#
#   Department_Name Class_Name
# 0        Intimate  Intimates

# %%
# Check whether the dataset contains duplicates
df.duplicated().sum()
# Out:
# 21

# %%
df[df.duplicated()]
# Out:
#        Clothing ID  Age Title  \
# 493           1104   39   NaN
# 2959          1094   30   NaN
# 4850           829   66   NaN
# 5671           861   34   NaN
# 5776           868   61   NaN
# 9306           834   70   NaN
# 9413          1094   39   NaN
# 9430          1094   36   NaN
# 10787         1078   35   NaN
# 14129          862   38   NaN
# 15954          872   36   NaN
# 17256          850   37   NaN
# 18747          828   46   NaN
# 18940         1078   35   NaN
# 20058          862   48   NaN
# 21888         1022   37   NaN
# 21959         1078   43   NaN
# 22246          895   36   NaN
# 23021          867   34   NaN
# 23258          862   35   NaN
# 23480          862   35   NaN
#
#                                              Review Text  Rating  \
# 493                                                  NaN       5
# 2959                                                 NaN       5
# 4850                                                 NaN       5
# 5671                                                 NaN       5
# 5776                                                 NaN       5
# 9306                                                 NaN       5
# 9413                                                 NaN       5
# 9430                                                 NaN       5
# 10787                                                NaN       5
# 14129                                                NaN       5
# 15954                                                NaN       5
# 17256                                                NaN       5
# 18747                                                NaN       5
# 18940                                                NaN       5
# 20058                                                NaN       5
# 21888  Love, love these jeans. being short they come ...       5
# 21959                                                NaN       5
# 22246                                                NaN       5
# 23021                                                NaN       5
# 23258                                                NaN       4
# 23480                                                NaN       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 493                  1                        0         General
# 2959                 1                        0         General
# 4850                 1                        0  General Petite
# 5671                 1                        0         General
# 5776                 1                        0         General
# 9306                 1                        0  General Petite
# 9413                 1                        0  General Petite
# 9430                 1                        0  General Petite
# 10787                1                        0         General
# 14129                1                        0  General Petite
# 15954                1                        0         General
# 17256                1                        0         General
# 18747                1                        0  General Petite
# 18940                1                        0  General Petite
# 20058                1                        0  General Petite
# 21888                1                        0         General
# 21959                1                        0         General
# 22246                1                        0  General Petite
# 23021                1                        0         General
# 23258                1                        0         General
# 23480                1                        0  General Petite
#
#       Department Name  Class Name
# 493           Dresses     Dresses
# 2959          Dresses     Dresses
# 4850             Tops     Blouses
# 5671             Tops       Knits
# 5776             Tops       Knits
# 9306             Tops     Blouses
# 9413          Dresses     Dresses
# 9430          Dresses     Dresses
# 10787         Dresses     Dresses
# 14129            Tops       Knits
# 15954            Tops       Knits
# 17256            Tops     Blouses
# 18747            Tops     Blouses
# 18940         Dresses     Dresses
# 20058            Tops       Knits
# 21888         Bottoms       Jeans
# 21959         Dresses     Dresses
# 22246            Tops  Fine gauge
# 23021            Tops       Knits
# 23258            Tops       Knits
# 23480            Tops       Knits

# %% [markdown]
# Notice that there are duplicated rows. But since there is no reviewer information in this dataset, it is difficult to judge whether these reviews are real duplicates of review or they are just from different reviewers but the reviewers have the same age and leaving no title and review text for these items. Since my goal is to analyze the Review Text, these duplicates are not informative due to lack of Review text. One exception is the item with index 21888, which does have a review text. This one may be a real duplicate.

# %%
df_1022 = df[df['Clothing ID'] == 1022]
df_1022[df_1022['Age']==37]
# Out:
#        Clothing ID  Age                 Title  \
# 1400          1022   37     Love these jeans!
# 9447          1022   37                   NaN
# 9722          1022   37  Classic ag greatness
# 9957          1022   37                   NaN
# 11429         1022   37          Unique style
# 21888         1022   37                   NaN
#
#                                              Review Text  Rating  \
# 1400   Great fit, perfect length! so happy with these...       5
# 9447   Love, love these jeans. being short they come ...       5
# 9722   These are awesome! classic style and quality y...       5
# 9957                                                 NaN       5
# 11429  These are nice cords, albeit they look slightl...       4
# 21888  Love, love these jeans. being short they come ...       5
#
#        Recommended IND  Positive Feedback Count Division Name Department Name  \
# 1400                 1                        3       General         Bottoms
# 9447                 1                        0       General         Bottoms
# 9722                 1                        0       General         Bottoms
# 9957                 1                        0       General         Bottoms
# 11429                1                        1       General         Bottoms
# 21888                1                        0       General         Bottoms
#
#       Class Name
# 1400       Jeans
# 9447       Jeans
# 9722       Jeans
# 9957       Jeans
# 11429      Jeans
# 21888      Jeans

# %% [markdown]
# ### Cleaning

# %%
# remove duplicates
df = df.drop_duplicates()

# %%
# remove nulls 
df = df[df['Review Text'].isnull() == False]

# %%
df.head()
# Out:
#    Clothing ID  Age                    Title  \
# 0          767   33                      NaN
# 1         1080   34                      NaN
# 2         1077   60  Some major design flaws
# 3         1049   50         My favorite buy!
# 4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22640 entries, 0 to 23485
# Data columns (total 10 columns):
# Clothing ID                22640 non-null int64
# Age                        22640 non-null int64
# Title                      19675 non-null object
# Review Text                22640 non-null object
# Rating                     22640 non-null int64
# Recommended IND            22640 non-null int64
# Positive Feedback Count    22640 non-null int64
# Division Name              22627 non-null object
# Department Name            22627 non-null object
# Class Name                 22627 non-null object
# dtypes: int64(5), object(5)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#         Clothing ID           Age        Rating  Recommended IND  \
# count  22640.000000  22640.000000  22640.000000     22640.000000
# mean     919.327827     43.280654      4.183525         0.818860
# std      202.270191     12.327181      1.115774         0.385142
# min        1.000000     18.000000      1.000000         0.000000
# 25%      861.000000     34.000000      4.000000         1.000000
# 50%      936.000000     41.000000      5.000000         1.000000
# 75%     1078.000000     52.000000      5.000000         1.000000
# max     1205.000000     99.000000      5.000000         1.000000
#
#        Positive Feedback Count
# count             22640.000000
# mean                  2.630698
# std                   5.786265
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                 122.000000

# %%
# Extracting Missing Count and Unique Count by Column
unique_count = []
for x in df.columns:
    unique_count.append([x,len(df[x].unique()),df[x].isnull().sum()])
pd.DataFrame(unique_count, columns=["Column","Unique","Missing"]).set_index("Column").T
# Out:
# Column   Unnamed: 0  Clothing ID  Age  Title  Review Text  Rating  \
# Unique        22641         1179   77  13993        22634       5
# Missing           0            0    0   2966            0       0
#
# Column   Recommended IND  Positive Feedback Count  Division Name  \
# Unique                 2                       82              4
# Missing                0                        0             13
#
# Column   Department Name  Class Name
# Unique                 7          21
# Missing               13          13

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# ### Univariate Distribution

# %%
# Check the age distribution
# ax = sns.distplot(df.Age)
# ax.set_title("Age Distribution")
# ax.set_ylabel("Density");
plt.hist(df.Age, bins = range(10,100,5))
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count");

# %%
# Check the rating distribution
np.min(df.Rating)
count_rating = []
for i in range(1,6):
    count_rating.append((df['Rating']== i).sum())
print("Positive Ratings (Rating >= 3): {0:.2f} %".format(df.query("Rating >= 3").count()[0]/df.shape[0] * 100) )
# Out:
# Positive Ratings (Rating >= 3): 89.53 %

# %%
plt.bar(range(1,6), count_rating, align='center')
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count");

# %%
# Check the distribution of Recommended IND 
np.min(df['Recommended_IND'])
count_recommend = []
for i in range(2):
    count_recommend.append((df['Recommended_IND']== i).sum())
print("Percentage of Recommended IND: {0:.2f}%".format(df.query("Recommended_IND == 1").count()[0]/df.shape[0]*100) )
# Out:
# Percentage of Recommended IND: 81.89%

# %%
plt.bar(range(2), count_recommend, tick_label = [0,1])
plt.title("Recommended IND Distribution")
plt.xlabel("Rating")
plt.ylabel("Count");

# %%
f, ax = plt.subplots(1,2,figsize=(12,4), sharey=False)
sns.distplot(df["Positive Feedback Count"], ax=ax[0])
ax[0].set_title("Positive Feedback Count Distribution")
ax[0].set_ylabel("Density")
sns.distplot(np.log10((df["Positive Feedback Count"][df["Positive Feedback Count"].notnull()]+1)), ax=ax[1])
ax[1].set_title("Positive Feedback Count Distribution\n[Log 10]")
ax[1].set_xlabel("Log Positive Feedback Count")
# Out:
# /anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,0,'Log Positive Feedback Count')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14,4), sharey=True)
ax1.axis('equal')
ax1.pie(df["Division_Name"].value_counts(), labels = df["Division_Name"].value_counts().index, radius = 1.5, autopct = '%0.1f%%')
ax1.set_title("Division Name", fontdict={'fontsize': 20}, pad = 50)
ax2.axis('equal')
ax2.pie(df["Department_Name"].value_counts(), labels= df["Department_Name"].value_counts().index, radius = 1.5, autopct='%0.1f%%')
ax2.set_title("Department Name", fontdict = {'fontsize': 20}, pad = 50)
plt.show()
